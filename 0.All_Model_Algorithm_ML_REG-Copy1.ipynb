# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler
scy=StandardScaler()
y_train = scy.fit_transform(y_train)
y_test = scy.transform(y_test)

# %%
# Grid Search CV Support Vector Machine
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(),param_grid,refit= True,verbose =3,n_jobs=-1)
grid.fit(X_train,y_train)
re=grid.cv_results_
print("The R_score Value for best parameter{}:",format(grid.best_params_))
table=pd.DataFrame.from_dict(re)
table
age_input =float(input("Age:"))
bmi_input =float(input("BMI:"))
children_input =float(input("Children:"))
sex_male_input =float(input("Sex male 0 or 1:"))
smoker_yes_input =float(input("Smoker Yes 0 or 1:"))
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}:".format(Future_Prediction))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(),param_grid,refit=True,verbose =3,n_jobs=-1)
grid.fit(X_train,y_train)
re=grid.cv_results_
print("The R_score Value for best parameter{}:",format(grid.best_params_))
# Out:
# C:\Users\skishor.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.8s
# The R_score Value for best parameter{}: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:  5.7min finished
# C:\Users\skishor.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\skishor.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.055115      0.005143         0.000314        0.000444      10
# 1        0.208326      0.044763         0.002152        0.002081      10
# 2        0.021793      0.002611         0.007092        0.006305      10
# 3        0.183219      0.024738         0.000331        0.000468      10
# 4        0.055122      0.005679         0.000446        0.000631      10
# 5        0.255505      0.064414         0.000000        0.000000      10
# 6        0.046914      0.015672         0.005315        0.004151      10
# 7        0.192807      0.017909         0.001093        0.001546      10
# 8        0.240670      0.025945         0.002484        0.003514     100
# 9        1.958837      0.239712         0.001269        0.001795     100
# 10       0.030473      0.001200         0.007968        0.003897     100
# 11       1.267649      0.054807         0.002488        0.003519     100
# 12       0.217854      0.030627         0.000000        0.000000     100
# 13       2.073118      0.251096         0.000000        0.000000     100
# 14       0.028697      0.002249         0.006598        0.000992     100
# 15       1.299428      0.065180         0.002852        0.004033     100
# 16       1.522526      0.108001         0.000000        0.000000    1000
# 17      42.748193      4.290192         0.000496        0.000702    1000
# 18       0.017272      0.000820         0.010796        0.007645    1000
# 19      25.612672      1.760466         0.009214        0.006971    1000
# 20       1.892155      0.707666         0.007495        0.006941    1000
# 21      39.041134      3.389100         0.005543        0.007838    1000
# 22       0.064490      0.011741         0.014591        0.003537    1000
# 23      29.171428      1.778874         0.000980        0.001386    1000
# 24       7.289733      0.634512         0.000164        0.000232    2000
# 25     102.055637     19.358103         0.005210        0.007368    2000
# 26       0.066085      0.004487         0.016332        0.000581    2000
# 27      53.876580      2.152653         0.008047        0.006176    2000
# 28       7.330760      0.226689         0.006461        0.006660    2000
# 29      96.061912     25.072472         0.000000        0.000000    2000
# 30       0.063953      0.011396         0.016093        0.000447    2000
# 31      55.713050      3.075056         0.000000        0.000000    2000
# 32      11.916906      1.420352         0.005211        0.007369    3000
# 33     152.474680      5.128135         0.000686        0.000970    3000
# 34       0.059210      0.007339         0.015821        0.000276    3000
# 35      80.693477      2.840040         0.000000        0.000000    3000
# 36      11.968064      0.972485         0.000000        0.000000    3000
# 37      98.333255     12.625180         0.000000        0.000000    3000
# 38       0.069182      0.009364         0.013874        0.002707    3000
# 39      52.118442     16.037602         0.000944        0.001335    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}       8.332925e-01
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}       8.216738e-01
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}      -2.022450e+03
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}       6.917877e-01
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}       8.333809e-01
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}       8.217678e-01
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}      -3.046467e+03
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}       6.917877e-01
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}       8.088294e-01
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}       8.223258e-01
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}      -3.121355e+05
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}       6.916730e-01
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}       8.088121e-01
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}       8.223247e-01
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}      -2.510636e+05
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}       6.916730e-01
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}       7.578936e-01
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}       8.224874e-01
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}      -3.021751e+07
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}       6.917066e-01
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}       7.591523e-01
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}       8.225422e-01
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...      -2.857892e+07
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}       6.917066e-01
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}       7.400140e-01
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}       8.224456e-01
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}      -1.197323e+08
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}       6.913112e-01
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}       7.397432e-01
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}       8.225247e-01
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...      -1.143167e+08
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}       6.913112e-01
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}       7.220322e-01
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}       8.225634e-01
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}      -2.693987e+08
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}       6.912879e-01
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}       7.241817e-01
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}       8.225957e-01
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...      -2.572132e+08
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}       6.912879e-01
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 
# 39       6.824518e-01       6.557468e-01     6.765121e-01    1.510813e-02
#
#     rank_test_score
# 0                 1
# 1                11
# 2                31
# 3                19
# 4                 2
# 5                12
# 6                32
# 7                19
# 8                13
# 9                10
# 10               34
# 11               21
# 12               14
# 13                8
# 14               33
# 15               21
# 16               25
# 17                5
# 18               35
# 19               15
# 20               26
# 21                7
# 22               36
# 23               15
# 24               27
# 25                6
# 26               37
# 27               17
# 28               28
# 29                4
# 30               38
# 31               17
# 32               29
# 33                9
# 34               39
# 35               23
# 36               30
# 37                3
# 38               40
# 39               23

# %%
# Grid Search CV DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['mse','mae','friedman_mse'],'max_features':['auto','sqrt','log2'],'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit= True,verbose =3,n_jobs=-1)
grid.fit(X_train,y_train)
re=grid.cv_results_
grid_predictions = grid.predict(X_test)
from sklearan.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score Value for best parameter{}:",format(grid.best_params_),r_score)
table=pd.DataFrame.from_dict(re)
table
age_input =float(input("Age:"))
bmi_input =float(input("BMI:"))
children_input =float(input("Children:"))
sex_male_input =float(input("Sex male 0 or 1:"))
smoker_yes_input =float(input("Smoker Yes 0 or 1:"))
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}:".format(Future_Prediction))

# %%
# Grid Search CV RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['mse','mae',],'max_features':['auto','sqrt','log2'],'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit= True,verbose =3,n_jobs=-1)
grid.fit(X_train,y_train)
re=grid.cv_results_
grid_predictions = grid.predict(X_test)
from sklearan.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score Value for best parameter{}:",format(grid.best_params_),r_score)
table=pd.DataFrame.from_dict(re)
table
age_input =float(input("Age:"))
bmi_input =float(input("BMI:"))
children_input =float(input("Children:"))
sex_male_input =float(input("Sex male 0 or 1:"))
smoker_yes_input =float(input("Smoker Yes 0 or 1:"))
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}:".format(Future_Prediction))

# %%
#Grid Search CV Random forest Regressor with out split Train,Test set
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['mse','mae',],'max_features':['auto','sqrt','log2'],'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit= True,verbose =3,n_jobs=-1)
grid.fit(independent,dependent)
re=grid.cv_results_
#grid_predictions = grid.predict(X_test)
#from sklearan.metrics import r2_score
#r_score=r2_score(y_test,grid_predictions)
print("The R_score Value for best parameter{}:",format(grid.best_params_))
table=pd.DataFrame.from_dict(re)
table
age_input =float(input("Age:"))
bmi_input =float(input("BMI:"))
children_input =float(input("Children:"))
sex_male_input =float(input("Sex male 0 or 1:"))
smoker_yes_input =float(input("Smoker Yes 0 or 1:"))
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}:".format(Future_Prediction))

# %%
#  Save the model load & test For preprocessed input 
import pickle
fileName="finalized_model.sav"

pickle.dump(regressor,open(fileName,'wb'))
# store or saving the regressor file /fileName 
# 'wb' means write  binary values 

preinput = sc.transform([[1234,345,4565,1,0]])
preinput
loaded_model=pickle.load(open("finalized_model.sav",'rb'))
# check the function  dumped in the pickle , need to load the pickle function from filename 
# 'rb' means read binary values
result=loaded_model.predict(preinput)
# predict function () double closesed paranthasise is used for predicting the values for different inputs
result

# %%
# DecisionTreeRegressor with out Grid

from sklearn.tree import DecisionTreeRegressor
#To reduce the memory import perticular small function(LinearRegression) from library (sklearn) ,Class (linear_model)
regressor=DecisionTreeRegressor(criterion='mae',splitter="best",max_features="auto")
#function()assigned to variable 1 for calling the function.
regressor.fit(X_train,y_train)
# Training set of X & Y  is feed into regressor for training
import matplotlib.pyplot as plt
from sklearn import tree
tree.plot_tree(regressor)
plt.show()
y_pred=regressor.predict(X_test)
# output prediction is assigned from regressor function And change with respect to X test
from sklearn.metrics import r2_score
#Import function r2_score from metrics class and sklearn library
r_score=r2_score(y_test,y_pred)
# to find r2_score value from outputof Test set(y_test), predicted output (y_pred)
r_score

# %%
#deployment for preprocessed input
import pickle
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,drop_first=True)
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
dependent=dataset[["charges"]]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
preinput = sc.transform([[1234,345,4565,1,0]])
preinput
loaded_model=pickle.load(open("finalized_model.sav",'rb'))
# check the function  dumped in the pickle , need to load the pickle function from filename 
# 'rb' means read binary values
result=loaded_model.predict(preinput)
# predict function () double closesed paranthasise is used for predicting the values for different inputs
result

# %%
#Save the model load & test for preprocessed input and output
import pickle
fileName="finalized_model.sav"
pickle.dump(re,open(fileName,'wb'))
preinput= sc.transform([[19,34.5,0,1,0]])
preinput
# Out:
# array([[-1.46814257,  0.62019647, -0.90788827,  1.01127431, -0.49929923]])

# %%
loaded_model=pickle.load(open("finalized_model.sav",'rb'))

# %%
Future_Prediction=grid.predict(preinput)
print("Future_Prediction={}:".format(Future_Prediction))
#result=loaded_model.predict()
# predict function () double closesed paranthasise is used for predicting the values for different inputs
# Out:
# Future_Prediction=[-0.90642597]:

# %%
preoutput = scy.inverse_transform([Future_Prediction])
preoutput
# Out:
# array([[2428.90170655]])

# %%
#deployment for preprocessed input and Output
import pickle
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,drop_first=True)
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
dependent=dataset[["charges"]]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)
#input pre process
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# output preprocess
from sklearn.preprocessing import StandardScaler
scy=StandardScaler()
y_train = scy.fit_transform(y_train)
y_test = sc.transform(y_test)
# User input preprocess
preinput = sc.transform([[1234,345,4565,1,0]])
preinput
loaded_model=pickle.load(open("finalized_model.sav",'rb'))
# check the function  dumped in the pickle , need to load the pickle function from filename 
# 'rb' means read binary values
result=loaded_model.predict(preinput)
# predict function () double closesed paranthasise is used for predicting the values for different inputs
result
# Output Inverse to preprocess
preoutput = scy.inverse_transform([result])
preoutput
